# %% [markdown]
# Klasifikasi Jenis Rempah-Rempah
# -Dataset
# https://www.kaggle.com/datasets/albertnathaniel12/indonesian-spices-dataset
# -References
# https://repository.ubaya.ac.id/44037/

# %%
# ====== 0. INSTALL & IMPORT ======
# !pip install -q kaggle seaborn scikit-learn

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
import os, shutil, zipfile
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

print("TensorFlow version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.20.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# 1. DOWNLOAD DATASET DARI KAGGLE

# %%
from google.colab import files
import os

# 1. Upload file kaggle.json dulu
files.upload() # nanti pilih file kaggle.json dari laptop

# 2. Pindahkan ke folder .kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# 3. Install kaggle + download dataset
# !pip install -q kaggle
# !kaggle datasets download -d albertnathaniel12/indonesian-spices-dataset -p /content
# !unzip -o -q /content/indonesian-spices-dataset.zip -d /content/data

DATA_DIR = "/content/data"
print("Selesai! Isi folder data:", os.listdir(DATA_DIR))
# Out:
#      <input type="file" id="files-9377cfb6-d8ec-4166-8869-394f54e65df2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9377cfb6-d8ec-4166-8869-394f54e65df2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 2. FILTER 5 KELAS

# %%
DATA_DIR = "/content/data/Indonesian Spices Dataset"
NEW_DATA_DIR = "/content/spices_5kelas"
CLASSES = ['kunyit', 'jahe', 'lengkuas', 'kayu manis', 'cengkeh']

print("Hapus folder lama dulu biar bersih...")
if os.path.exists(NEW_DATA_DIR):
    shutil.rmtree(NEW_DATA_DIR) # hapus folder lama

print("Membuat folder 5 kelas...")
os.makedirs(NEW_DATA_DIR)

for cls in CLASSES:
    found = [f for f in os.listdir(DATA_DIR) if f.lower() == cls.lower()]
    if found:
        src = os.path.join(DATA_DIR, found[0])
        dst = os.path.join(NEW_DATA_DIR, cls)
        shutil.copytree(src, dst)
        print(f"Copied: {found[0]} - {len(os.listdir(src))} gambar")
    else:
        print(f"ERROR: Folder {cls} tidak ditemukan")

print("\nSelesai! Cek isi:", os.listdir(NEW_DATA_DIR))
# Out:
# Hapus folder lama dulu biar bersih...
# Membuat folder 5 kelas...
# Copied: kunyit - 210 gambar
# Copied: jahe - 210 gambar
# Copied: lengkuas - 210 gambar
# Copied: kayu manis - 210 gambar
# Copied: cengkeh - 210 gambar
#
# Selesai! Cek isi: ['kayu manis', 'jahe', 'kunyit', 'lengkuas', 'cengkeh']

# %% [markdown]
# 3. DATA GENERATOR DAN AUGMENTATION

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 224
BATCH_SIZE = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    NEW_DATA_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    NEW_DATA_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

print("Class indices:", train_generator.class_indices)
# Out:
# Found 840 images belonging to 5 classes.
# Found 210 images belonging to 5 classes.
# Class indices: {'cengkeh': 0, 'jahe': 1, 'kayu manis': 2, 'kunyit': 3, 'lengkuas': 4}

# %% [markdown]
# 4. ARSITEKTUR CNN

# %% [markdown]
# Model Cnn

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5), # biar gak overfitting
    Dense(5, activation='softmax') # 5 kelas
])

model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# 5. TRAINING

# %%
EPOCHS = 15

history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // BATCH_SIZE,
    validation_data = validation_generator,
    validation_steps = validation_generator.samples // BATCH_SIZE,
    epochs = EPOCHS
)
# Out:
# Epoch 1/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 27s 734ms/step - accuracy: 0.2921 - loss: 1.5429 - val_accuracy: 0.4427 - val_loss: 1.3928
# Epoch 2/15
#  1/26 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.4062 - loss: 1.4407
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.4062 - loss: 1.4407 - val_accuracy: 0.4167 - val_loss: 1.4002
# Epoch 3/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 568ms/step - accuracy: 0.4480 - loss: 1.3240 - val_accuracy: 0.5052 - val_loss: 1.2097
# Epoch 4/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.5625 - loss: 1.1461 - val_accuracy: 0.4948 - val_loss: 1.2277
# Epoch 5/15
# ...

# %% [markdown]
# Simpan dan download model

# %%
model.save('model_rempah_5kelas.h5')
print("Model berhasil disimpan!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model berhasil disimpan!

# %%
from google.colab import files
files.download('model_rempah_5kelas.h5')

# %% [markdown]
# 6. PLOT AKURASI DAN LOSS

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(15)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Akurasi Training vs Validasi')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Loss Training vs Validasi')  # <-- ini udah aku tutup kutipnya

plt.show()

# %% [markdown]
# 7. CONFUSION MATRIX DAN CLASSIFICATION REPORT

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import numpy as np

Y_pred = model.predict(validation_generator)
y_pred = np.argmax(Y_pred, axis=1)
y_true = validation_generator.classes
class_labels = list(validation_generator.class_indices.keys())

print("=== CLASSIFICATION REPORT ===")
print(classification_report(y_true, y_pred, target_names=class_labels))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix'); plt.xlabel('Prediksi'); plt.ylabel('Asli')
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step
# === CLASSIFICATION REPORT ===
#               precision    recall  f1-score   support
#
#      cengkeh       0.18      0.17      0.17        42
#         jahe       0.37      0.38      0.38        42
#   kayu manis       0.33      0.10      0.15        42
#       kunyit       0.31      0.45      0.37        42
#     lengkuas       0.16      0.21      0.19        42
#
#     accuracy                           0.26       210
#    macro avg       0.27      0.26      0.25       210
# weighted avg       0.27      0.26      0.25       210

# %% [markdown]
# 8. TES PREDIKSI UPLOAD GAMBAR

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from google.colab import files
import matplotlib.pyplot as plt

print("Silakan pilih BEBERAPA foto rempah... tahan CTRL buat pilih banyak")
uploaded = files.upload() # <-- ini bisa pilih banyak file

kelas = list(train_generator.class_indices.keys())

for fn in uploaded.keys():
    path = fn

    # Tampilkan gambar
    img = image.load_img(path, target_size=(224, 224))
    plt.figure(figsize=(3,3))
    plt.imshow(img)
    plt.title(f"Gambar: {fn}")
    plt.axis('off')
    plt.show()

    # Prediksi
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0

    prediksi = model.predict(img_array)
    hasil = kelas[np.argmax(prediksi)]

    print(f"🎯 Model menebak: **{hasil.upper()}**")
    print(f"📊 Probabilitas: {np.max(prediksi)*100:.2f}%")
    print("="*30)
# Out:
# Silakan pilih BEBERAPA foto rempah... tahan CTRL buat pilih banyak
#      <input type="file" id="files-2526bf99-4f44-489c-bfa9-2a78bd507070" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2526bf99-4f44-489c-bfa9-2a78bd507070">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
